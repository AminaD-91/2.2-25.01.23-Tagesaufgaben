# %% [markdown]
# <center><h1 style="font-size:2em;color:#2467C0;font-family:Times New Roman">Tagesaufgaben 25.01.2023</h1></center>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   <hr>
#       <h4 style="font-family:courier;font-size:1.3em">
# Lade die CSV Datei 'Dataset.csv' herunter und speichere sie in einem gewünschten Ordner auf deinem Rechner.
# </h4>
# <hr>
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#           <h4 style="font-family:courier;font-size:1.7em">
# Aufgabe1
# </h4>
#   <hr>
#       <h4 style="font-family:courier;font-size:1.5em">
# Bearbeite die angegebenen Steps<br>
# </h4>
# </div>

# %% [markdown]
# # Step1
# ### Lese die  'Dataset.csv' Datei  und speichere den Dataframe in der Variable 'data'. Gib anschließend die ersten 4 Zeilen des Dataframes aus.

# %%
import pandas as pd
data= pd.read_csv(r"C:\Users\Admin\Downloads\Dataset.csv")
data.head(4)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_19064\4005682511.py:2: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   data= pd.read_csv(r"C:\Users\Admin\Downloads\Dataset.csv")
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# 3           11/07/2016  0156  011           1230                  NaN
#
#   Street Name Street Suffix  ...  Existing Construction Type  \
# 0       Ellis            St  ...                         3.0
# 1       Geary            St  ...                         3.0
# 2     Pacific            Av  ...                         1.0
# 3     Pacific            Av  ...                         5.0
#
#   Existing Construction Type Description Proposed Construction Type  \
# 0                          constr type 3                        NaN
# 1                          constr type 3                        NaN
# 2                          constr type 1                        1.0
# 3                         wood frame (5)                        5.0
#
#   Proposed Construction Type Description Site Permit Supervisor District  \
# 0                                    NaN         NaN                 3.0
# 1                                    NaN         NaN                 3.0
# 2                          constr type 1         NaN                 3.0
# 3                         wood frame (5)         NaN                 3.0
#
#   Neighborhoods - Analysis Boundaries  Zipcode  \
# 0                          Tenderloin  94102.0
# 1                          Tenderloin  94102.0
# 2                        Russian Hill  94109.0
# 3                            Nob Hill  94109.0
#
#                                     Location      Record ID
# 0  (37.785719256680785, -122.40852313194863)  1380611233945
# 1   (37.78733980600732, -122.41063199757738)  1420164406718
# 2    (37.7946573324287, -122.42232562979227)  1424856504716
# 3   (37.79595867909168, -122.41557405519474)  1443574295566
#
# [4 rows x 43 columns]

# %% [markdown]
# # Step2
# ## Berechne die Menge an NaNs in jeder Spalte und lass dir die 10 Spalten mit den meisten NaNs anzeigen.

# %%
Nan_count = data.isna().sum()
Nan_count = Nan_count.sort_values(ascending =False )
Nan_count[:10]
# Out:
# TIDF Compliance                  198898
# Voluntary Soft-Story Retrofit    198865
# Unit Suffix                      196939
# Street Number Suffix             196684
# Site Permit                      193541
# Structural Notification          191978
# Fire Only Permit                 180073
# Unit                             169421
# Completed Date                   101709
# Permit Expiration Date            51880
# dtype: int64

# %%
Nan_count = data.isnull().sum()
Nan_count = Nan_count.sort_values(ascending =False )
Nan_count[:10]
# Out:
# TIDF Compliance                  198898
# Voluntary Soft-Story Retrofit    198865
# Unit Suffix                      196939
# Street Number Suffix             196684
# Site Permit                      193541
# Structural Notification          191978
# Fire Only Permit                 180073
# Unit                             169421
# Completed Date                   101709
# Permit Expiration Date            51880
# dtype: int64

# %% [markdown]
# # Step 3
# ### Lösche die Spalten in denen mehr als 50% der Werte NaNs sind. Überschreibe dazu deinen DataFrame.

# %%
data.dropna(thresh=data.shape[0]*0.5, axis=1, inplace=True)
data
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 198895       M862628            8            otc alterations permit
# 198896  201712055595            8            otc alterations permit
# 198897       M863507            8            otc alterations permit
# 198898       M863747            8            otc alterations permit
# 198899       M864287            8            otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Name  \
# 0                05/06/2015  0326   023            140       Ellis
# 1                04/19/2016  0306   007            440       Geary
# 2                05/27/2016  0595   203           1647     Pacific
# 3                11/07/2016  0156   011           1230     Pacific
# 4                11/28/2016  0342   001            950      Market
# ...                     ...   ...   ...            ...         ...
# 198895           12/05/2017  0113  017A           1228  Montgomery
# 198896           12/05/2017  0271   014            580        Bush
# 198897           12/06/2017  4318   019           1568     Indiana
# 198898           12/06/2017  0298   029            795      Sutter
# 198899           12/07/2017  0160   006            838     Pacific
#
#        Street Suffix                                        Description  ...  \
# 0                 St  ground fl facade: to erect illuminated, electr...  ...
# 1                 St            remove (e) awning and associated signs.  ...
# 2                 Av                    installation of separating wall  ...
# 3                 Av           repair dryrot & stucco at front of bldg.  ...
# 4                 St  demolish retail/office/commercial 3-story buil...  ...
# ...              ...                                                ...  ...
# 198895            St                                       street space  ...
# 198896            St                fire alarm upgrade ref 201704123852  ...
# 198897            St                                       street space  ...
# 198898            St                                street space permit  ...
# 198899            Av                                street space permit  ...
#
#        Plansets Existing Construction Type  \
# 0           2.0                        3.0
# 1           2.0                        3.0
# 2           2.0                        1.0
# 3           2.0                        5.0
# 4           2.0                        3.0
# ...         ...                        ...
# 198895      NaN                        NaN
# 198896      2.0                        5.0
# 198897      NaN                        NaN
# 198898      NaN                        NaN
# 198899      NaN                        NaN
#
#        Existing Construction Type Description Proposed Construction Type  \
# 0                               constr type 3                        NaN
# 1                               constr type 3                        NaN
# 2                               constr type 1                        1.0
# 3                              wood frame (5)                        5.0
# 4                               constr type 3                        NaN
# ...                                       ...                        ...
# 198895                                    NaN                        NaN
# 198896                         wood frame (5)                        5.0
# 198897                                    NaN                        NaN
# 198898                                    NaN                        NaN
# 198899                                    NaN                        NaN
#
#        Proposed Construction Type Description  Supervisor District  \
# 0                                         NaN                  3.0
# 1                                         NaN                  3.0
# 2                               constr type 1                  3.0
# 3                              wood frame (5)                  3.0
# 4                                         NaN                  6.0
# ...                                       ...                  ...
# 198895                                    NaN                  NaN
# 198896                         wood frame (5)                  NaN
# 198897                                    NaN                  NaN
# 198898                                    NaN                  NaN
# 198899                                    NaN                  NaN
#
#         Neighborhoods - Analysis Boundaries  Zipcode  \
# 0                                Tenderloin  94102.0
# 1                                Tenderloin  94102.0
# 2                              Russian Hill  94109.0
# 3                                  Nob Hill  94109.0
# 4                                Tenderloin  94102.0
# ...                                     ...      ...
# 198895                                  NaN      NaN
# 198896                                  NaN      NaN
# 198897                                  NaN      NaN
# 198898                                  NaN      NaN
# 198899                                  NaN      NaN
#
#                                          Location      Record ID
# 0       (37.785719256680785, -122.40852313194863)  1380611233945
# 1        (37.78733980600732, -122.41063199757738)  1420164406718
# 2         (37.7946573324287, -122.42232562979227)  1424856504716
# 3        (37.79595867909168, -122.41557405519474)  1443574295566
# 4        (37.78315261897309, -122.40950883997789)   144548169992
# ...                                           ...            ...
# 198895                                        NaN  1489337276729
# 198896                                        NaN  1489462354993
# 198897                                        NaN  1489539379952
# 198898                                        NaN  1489608233656
# 198899                                        NaN  1489796283803
#
# [198900 rows x 34 columns]

# %%
data1 = data[list(data.columns[Nan_count<0.5]) ]
data1
# Out:
#         Plansets TIDF Compliance  Existing Construction Type  \
# 0            2.0             NaN                         3.0
# 1            2.0             NaN                         3.0
# 2            2.0             NaN                         1.0
# 3            2.0             NaN                         5.0
# 4            2.0             NaN                         3.0
# ...          ...             ...                         ...
# 198895       NaN             NaN                         NaN
# 198896       2.0             NaN                         5.0
# 198897       NaN             NaN                         NaN
# 198898       NaN             NaN                         NaN
# 198899       NaN             NaN                         NaN
#
#        Existing Construction Type Description  Proposed Construction Type  \
# 0                               constr type 3                         NaN
# 1                               constr type 3                         NaN
# 2                               constr type 1                         1.0
# 3                              wood frame (5)                         5.0
# 4                               constr type 3                         NaN
# ...                                       ...                         ...
# 198895                                    NaN                         NaN
# 198896                         wood frame (5)                         5.0
# 198897                                    NaN                         NaN
# 198898                                    NaN                         NaN
# 198899                                    NaN                         NaN
#
#        Proposed Construction Type Description Site Permit  \
# 0                                         NaN         NaN
# 1                                         NaN         NaN
# 2                               constr type 1         NaN
# 3                              wood frame (5)         NaN
# 4                                         NaN         NaN
# ...                                       ...         ...
# 198895                                    NaN         NaN
# 198896                         wood frame (5)         NaN
# 198897                                    NaN         NaN
# 198898                                    NaN         NaN
# 198899                                    NaN         NaN
#
#         Supervisor District Neighborhoods - Analysis Boundaries  Zipcode  \
# 0                       3.0                          Tenderloin  94102.0
# 1                       3.0                          Tenderloin  94102.0
# 2                       3.0                        Russian Hill  94109.0
# 3                       3.0                            Nob Hill  94109.0
# 4                       6.0                          Tenderloin  94102.0
# ...                     ...                                 ...      ...
# 198895                  NaN                                 NaN      NaN
# 198896                  NaN                                 NaN      NaN
# 198897                  NaN                                 NaN      NaN
# 198898                  NaN                                 NaN      NaN
# 198899                  NaN                                 NaN      NaN
#
#                                          Location      Record ID
# 0       (37.785719256680785, -122.40852313194863)  1380611233945
# 1        (37.78733980600732, -122.41063199757738)  1420164406718
# 2         (37.7946573324287, -122.42232562979227)  1424856504716
# 3        (37.79595867909168, -122.41557405519474)  1443574295566
# 4        (37.78315261897309, -122.40950883997789)   144548169992
# ...                                           ...            ...
# 198895                                        NaN  1489337276729
# 198896                                        NaN  1489462354993
# 198897                                        NaN  1489539379952
# 198898                                        NaN  1489608233656
# 198899                                        NaN  1489796283803
#
# [198900 rows x 12 columns]

# %% [markdown]
# # Step 4 - Optional
# ### Prozentual gesehen, wie viele NaN Werte gibt es im ganzen DataFrame?

# %%
a = data.isnull().sum().sum()/data.size
a
# Out:
# 0.08503371484340343

# %% [markdown]
# # Step 5
# ### Zeige mithilfe der missingno Library alle NaN Werte in einem Graphen an

# %%
import missingno as msno
msno.matrix(data)
# Out:
# <AxesSubplot: >

# %%
msno.heatmap(data)
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Step 6 - Optional
# ## Fülle alle NaN Werte in der Spalte "Existing Use" mit dem darüberliegenden NICHT NaN Wert!
# ## Lass dir das Ergebnis nur anzeigen und überschreibe den DataFrame nicht!
# ### Die beiden folgenden Tabellen sind Beispiele zur Veranschaulichung. Die erste zeigt die Ausgangstabelle und die zweite das Ergebnis nach Anwendung des zweiten Schrittes.

# %% [markdown]
# Spalte 1 | Spalte 2
# -------- | --------
# 2   | 1
#  3  | NaN
# NaN | 7
# NaN   | NaN

# %% [markdown]
# ##### Endergebnis
# Spalte 1 | Spalte 2
# -------- | --------
# 2   | 1
#  3  | 1
# 3 | 7
# 3   | 7

# %% [markdown]
# # Step 7
# ## Ersetze die NaN Werte in der Spalte "Number of Existing Stories"  mit einer 1

# %%
data['Number of Existing Stories'].fillna(1, inplace=True)
data
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 198895       M862628            8            otc alterations permit
# 198896  201712055595            8            otc alterations permit
# 198897       M863507            8            otc alterations permit
# 198898       M863747            8            otc alterations permit
# 198899       M864287            8            otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Name  \
# 0                05/06/2015  0326   023            140       Ellis
# 1                04/19/2016  0306   007            440       Geary
# 2                05/27/2016  0595   203           1647     Pacific
# 3                11/07/2016  0156   011           1230     Pacific
# 4                11/28/2016  0342   001            950      Market
# ...                     ...   ...   ...            ...         ...
# 198895           12/05/2017  0113  017A           1228  Montgomery
# 198896           12/05/2017  0271   014            580        Bush
# 198897           12/06/2017  4318   019           1568     Indiana
# 198898           12/06/2017  0298   029            795      Sutter
# 198899           12/07/2017  0160   006            838     Pacific
#
#        Street Suffix                                        Description  ...  \
# 0                 St  ground fl facade: to erect illuminated, electr...  ...
# 1                 St            remove (e) awning and associated signs.  ...
# 2                 Av                    installation of separating wall  ...
# 3                 Av           repair dryrot & stucco at front of bldg.  ...
# 4                 St  demolish retail/office/commercial 3-story buil...  ...
# ...              ...                                                ...  ...
# 198895            St                                       street space  ...
# 198896            St                fire alarm upgrade ref 201704123852  ...
# 198897            St                                       street space  ...
# 198898            St                                street space permit  ...
# 198899            Av                                street space permit  ...
#
#        Plansets Existing Construction Type  \
# 0           2.0                        3.0
# 1           2.0                        3.0
# 2           2.0                        1.0
# 3           2.0                        5.0
# 4           2.0                        3.0
# ...         ...                        ...
# 198895      NaN                        NaN
# 198896      2.0                        5.0
# 198897      NaN                        NaN
# 198898      NaN                        NaN
# 198899      NaN                        NaN
#
#        Existing Construction Type Description Proposed Construction Type  \
# 0                               constr type 3                        NaN
# 1                               constr type 3                        NaN
# 2                               constr type 1                        1.0
# 3                              wood frame (5)                        5.0
# 4                               constr type 3                        NaN
# ...                                       ...                        ...
# 198895                                    NaN                        NaN
# 198896                         wood frame (5)                        5.0
# 198897                                    NaN                        NaN
# 198898                                    NaN                        NaN
# 198899                                    NaN                        NaN
#
#        Proposed Construction Type Description  Supervisor District  \
# 0                                         NaN                  3.0
# 1                                         NaN                  3.0
# 2                               constr type 1                  3.0
# 3                              wood frame (5)                  3.0
# 4                                         NaN                  6.0
# ...                                       ...                  ...
# 198895                                    NaN                  NaN
# 198896                         wood frame (5)                  NaN
# 198897                                    NaN                  NaN
# 198898                                    NaN                  NaN
# 198899                                    NaN                  NaN
#
#         Neighborhoods - Analysis Boundaries  Zipcode  \
# 0                                Tenderloin  94102.0
# 1                                Tenderloin  94102.0
# 2                              Russian Hill  94109.0
# 3                                  Nob Hill  94109.0
# 4                                Tenderloin  94102.0
# ...                                     ...      ...
# 198895                                  NaN      NaN
# 198896                                  NaN      NaN
# 198897                                  NaN      NaN
# 198898                                  NaN      NaN
# 198899                                  NaN      NaN
#
#                                          Location      Record ID
# 0       (37.785719256680785, -122.40852313194863)  1380611233945
# 1        (37.78733980600732, -122.41063199757738)  1420164406718
# 2         (37.7946573324287, -122.42232562979227)  1424856504716
# 3        (37.79595867909168, -122.41557405519474)  1443574295566
# 4        (37.78315261897309, -122.40950883997789)   144548169992
# ...                                           ...            ...
# 198895                                        NaN  1489337276729
# 198896                                        NaN  1489462354993
# 198897                                        NaN  1489539379952
# 198898                                        NaN  1489608233656
# 198899                                        NaN  1489796283803
#
# [198900 rows x 34 columns]

# %% [markdown]
# # Step 8
# ## Ersetze die NaN Werte in der Spalte "Existing Units"  mit dem Maximalwert dieser Spalte

# %%
data['Existing Units'].fillna(data['Existing Units'].max(), inplace=True)
data
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 198895       M862628            8            otc alterations permit
# 198896  201712055595            8            otc alterations permit
# 198897       M863507            8            otc alterations permit
# 198898       M863747            8            otc alterations permit
# 198899       M864287            8            otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Name  \
# 0                05/06/2015  0326   023            140       Ellis
# 1                04/19/2016  0306   007            440       Geary
# 2                05/27/2016  0595   203           1647     Pacific
# 3                11/07/2016  0156   011           1230     Pacific
# 4                11/28/2016  0342   001            950      Market
# ...                     ...   ...   ...            ...         ...
# 198895           12/05/2017  0113  017A           1228  Montgomery
# 198896           12/05/2017  0271   014            580        Bush
# 198897           12/06/2017  4318   019           1568     Indiana
# 198898           12/06/2017  0298   029            795      Sutter
# 198899           12/07/2017  0160   006            838     Pacific
#
#        Street Suffix                                        Description  ...  \
# 0                 St  ground fl facade: to erect illuminated, electr...  ...
# 1                 St            remove (e) awning and associated signs.  ...
# 2                 Av                    installation of separating wall  ...
# 3                 Av           repair dryrot & stucco at front of bldg.  ...
# 4                 St  demolish retail/office/commercial 3-story buil...  ...
# ...              ...                                                ...  ...
# 198895            St                                       street space  ...
# 198896            St                fire alarm upgrade ref 201704123852  ...
# 198897            St                                       street space  ...
# 198898            St                                street space permit  ...
# 198899            Av                                street space permit  ...
#
#        Plansets Existing Construction Type  \
# 0           2.0                        3.0
# 1           2.0                        3.0
# 2           2.0                        1.0
# 3           2.0                        5.0
# 4           2.0                        3.0
# ...         ...                        ...
# 198895      NaN                        NaN
# 198896      2.0                        5.0
# 198897      NaN                        NaN
# 198898      NaN                        NaN
# 198899      NaN                        NaN
#
#        Existing Construction Type Description Proposed Construction Type  \
# 0                               constr type 3                        NaN
# 1                               constr type 3                        NaN
# 2                               constr type 1                        1.0
# 3                              wood frame (5)                        5.0
# 4                               constr type 3                        NaN
# ...                                       ...                        ...
# 198895                                    NaN                        NaN
# 198896                         wood frame (5)                        5.0
# 198897                                    NaN                        NaN
# 198898                                    NaN                        NaN
# 198899                                    NaN                        NaN
#
#        Proposed Construction Type Description  Supervisor District  \
# 0                                         NaN                  3.0
# 1                                         NaN                  3.0
# 2                               constr type 1                  3.0
# 3                              wood frame (5)                  3.0
# 4                                         NaN                  6.0
# ...                                       ...                  ...
# 198895                                    NaN                  NaN
# 198896                         wood frame (5)                  NaN
# 198897                                    NaN                  NaN
# 198898                                    NaN                  NaN
# 198899                                    NaN                  NaN
#
#         Neighborhoods - Analysis Boundaries  Zipcode  \
# 0                                Tenderloin  94102.0
# 1                                Tenderloin  94102.0
# 2                              Russian Hill  94109.0
# 3                                  Nob Hill  94109.0
# 4                                Tenderloin  94102.0
# ...                                     ...      ...
# 198895                                  NaN      NaN
# 198896                                  NaN      NaN
# 198897                                  NaN      NaN
# 198898                                  NaN      NaN
# 198899                                  NaN      NaN
#
#                                          Location      Record ID
# 0       (37.785719256680785, -122.40852313194863)  1380611233945
# 1        (37.78733980600732, -122.41063199757738)  1420164406718
# 2         (37.7946573324287, -122.42232562979227)  1424856504716
# 3        (37.79595867909168, -122.41557405519474)  1443574295566
# 4        (37.78315261897309, -122.40950883997789)   144548169992
# ...                                           ...            ...
# 198895                                        NaN  1489337276729
# 198896                                        NaN  1489462354993
# 198897                                        NaN  1489539379952
# 198898                                        NaN  1489608233656
# 198899                                        NaN  1489796283803
#
# [198900 rows x 34 columns]

# %% [markdown]
# # Step 9
# ## Ersetze die NaN Werte in der Spalte "Plansets"  mit einer linearen Interpolation

# %%
data["Plansets"].interpolate(method='linear', inplace=True)
data
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 198895       M862628            8            otc alterations permit
# 198896  201712055595            8            otc alterations permit
# 198897       M863507            8            otc alterations permit
# 198898       M863747            8            otc alterations permit
# 198899       M864287            8            otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Name  \
# 0                05/06/2015  0326   023            140       Ellis
# 1                04/19/2016  0306   007            440       Geary
# 2                05/27/2016  0595   203           1647     Pacific
# 3                11/07/2016  0156   011           1230     Pacific
# 4                11/28/2016  0342   001            950      Market
# ...                     ...   ...   ...            ...         ...
# 198895           12/05/2017  0113  017A           1228  Montgomery
# 198896           12/05/2017  0271   014            580        Bush
# 198897           12/06/2017  4318   019           1568     Indiana
# 198898           12/06/2017  0298   029            795      Sutter
# 198899           12/07/2017  0160   006            838     Pacific
#
#        Street Suffix                                        Description  ...  \
# 0                 St  ground fl facade: to erect illuminated, electr...  ...
# 1                 St            remove (e) awning and associated signs.  ...
# 2                 Av                    installation of separating wall  ...
# 3                 Av           repair dryrot & stucco at front of bldg.  ...
# 4                 St  demolish retail/office/commercial 3-story buil...  ...
# ...              ...                                                ...  ...
# 198895            St                                       street space  ...
# 198896            St                fire alarm upgrade ref 201704123852  ...
# 198897            St                                       street space  ...
# 198898            St                                street space permit  ...
# 198899            Av                                street space permit  ...
#
#        Plansets Existing Construction Type  \
# 0           2.0                        3.0
# 1           2.0                        3.0
# 2           2.0                        1.0
# 3           2.0                        5.0
# 4           2.0                        3.0
# ...         ...                        ...
# 198895      1.0                        NaN
# 198896      2.0                        5.0
# 198897      2.0                        NaN
# 198898      2.0                        NaN
# 198899      2.0                        NaN
#
#        Existing Construction Type Description Proposed Construction Type  \
# 0                               constr type 3                        NaN
# 1                               constr type 3                        NaN
# 2                               constr type 1                        1.0
# 3                              wood frame (5)                        5.0
# 4                               constr type 3                        NaN
# ...                                       ...                        ...
# 198895                                    NaN                        NaN
# 198896                         wood frame (5)                        5.0
# 198897                                    NaN                        NaN
# 198898                                    NaN                        NaN
# 198899                                    NaN                        NaN
#
#        Proposed Construction Type Description  Supervisor District  \
# 0                                         NaN                  3.0
# 1                                         NaN                  3.0
# 2                               constr type 1                  3.0
# 3                              wood frame (5)                  3.0
# 4                                         NaN                  6.0
# ...                                       ...                  ...
# 198895                                    NaN                  NaN
# 198896                         wood frame (5)                  NaN
# 198897                                    NaN                  NaN
# 198898                                    NaN                  NaN
# 198899                                    NaN                  NaN
#
#         Neighborhoods - Analysis Boundaries  Zipcode  \
# 0                                Tenderloin  94102.0
# 1                                Tenderloin  94102.0
# 2                              Russian Hill  94109.0
# 3                                  Nob Hill  94109.0
# 4                                Tenderloin  94102.0
# ...                                     ...      ...
# 198895                                  NaN      NaN
# 198896                                  NaN      NaN
# 198897                                  NaN      NaN
# 198898                                  NaN      NaN
# 198899                                  NaN      NaN
#
#                                          Location      Record ID
# 0       (37.785719256680785, -122.40852313194863)  1380611233945
# 1        (37.78733980600732, -122.41063199757738)  1420164406718
# 2         (37.7946573324287, -122.42232562979227)  1424856504716
# 3        (37.79595867909168, -122.41557405519474)  1443574295566
# 4        (37.78315261897309, -122.40950883997789)   144548169992
# ...                                           ...            ...
# 198895                                        NaN  1489337276729
# 198896                                        NaN  1489462354993
# 198897                                        NaN  1489539379952
# 198898                                        NaN  1489608233656
# 198899                                        NaN  1489796283803
#
# [198900 rows x 34 columns]

# %% [markdown]
# # Step 10
# ### Lade das aktualisierte Notebook auf den Server (Github)

# %% [markdown]
# <div class="alert alert-success" role="alert">
#           <h4 style="font-family:courier;font-size:1.7em">
# Aufgabe2 - SQL
# </h4>
#   <hr>
#       <h4 style="font-family:courier;font-size:1.5em">
#
# </h4>
# </div>

# %% [markdown]
# Wie nennt man in SQL folgende Begriffe:

# %% [markdown]
# Tabelle:table
# Zeilen:rows
# Spalten:columns

# %% [markdown]
# Welche Eigenschaften sollten Transaktionen besitzen? Nenne das Schlagwort und erläutere die einzelnen Bestandteile

# %% [markdown]
# #Atomarität/Abgeschlossenheit: Ganz oder gar nicht
# ○ Konsistenz: Transaktion hinterläßt konsistenten Datenbankzustand
# ○ Isolation: Nebenläufige Transaktionen beeinflußen sich nicht (Sperrverfahren)
# ○ Dauerhaftigkeit: dauerhafte Speicherung
# ● Alle relationalen DBMS sind ACID-conform
#
# ● wesentlicher Unterschied zu NoSQL
